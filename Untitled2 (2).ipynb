# %%
import pandas as pd
df=pd.read_csv("data.csv")
#dropping useless column
df=df.dropna(axis=1)
print(df.shape)
b=[]
# Out:
# (569, 32)

# %%
print(df)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
import seaborn as sns
sns.countplot(data=df,x='diagnosis')
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,12))
#corr=df[['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean']].corr()
#print(corr)
#corr=df.iloc[:,1:12].corr()
corr=df.iloc[:,2:31].corr()
sns.heatmap(corr,fmt="0.2f",linewidths=1,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df.iloc[:,1:12],hue='diagnosis')
#print(corr)

# %%
sns.barplot(data=df,x='diagnosis',y='radius_mean')
sns.barplot(data=df,x='diagnosis',y='texture_mean')
sns.barplot(data=df,x='diagnosis',y='perimeter_mean')
sns.barplot(data=df,x='diagnosis',y='area_mean')
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='area_mean'>

# %%
sns.scatterplot(x=df['texture_mean'],y=df['radius_mean'],hue=df['diagnosis'])
# Out:
# <AxesSubplot:xlabel='texture_mean', ylabel='radius_mean'>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.boxplot(df.iloc[:,2:12])
plt.show()
#print(df.iloc[:,2])

# %%
sns.histplot(data=df,hue='diagnosis',x='radius_mean')
# Out:
# <AxesSubplot:xlabel='radius_mean', ylabel='Count'>

# %%
df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
#x=df[['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean']]
y=df['diagnosis']
x=df.iloc[:,2:12]
print(x)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
#print(x_train)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score
y_pred=svc.predict(x_test)
print(b.append(accuracy_score(y_pred,y_test)))
print(l.pop())
print(b)
# Out:
# None
# 0.8771929824561403
# [0.8771929824561403]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.97      0.85      0.91       123
#            M       0.71      0.94      0.81        48
#
#     accuracy                           0.88       171
#    macro avg       0.84      0.90      0.86       171
# weighted avg       0.90      0.88      0.88       171

# %%
from sklearn.metrics import confusion_matrix
z=confusion_matrix(y_pred,y_test)

# %%
sns.heatmap(z,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_std=sc.fit_transform(x_train)
x_test_std=sc.fit_transform(x_test)
print(x_train_std)
# Out:
# [[-0.74998027 -1.09978744 -0.74158608 ... -0.7605498  -0.09986038
#    0.45144364]
#  [-1.02821446 -0.1392617  -1.02980434 ... -0.80880455 -1.15975947
#    0.48938568]
#  [-0.53852228 -0.29934933 -0.56857428 ... -0.66812536  0.58175823
#   -0.05347746]
#  ...
#  [-1.3214733  -0.20855336 -1.3143845  ... -0.90429278 -1.07411106
#    1.0132778 ]
#  [-1.24245479 -0.23244704 -1.27759928 ... -1.26326726 -0.54951454
#    0.26611133]
#  [-0.74441558  1.13188181 -0.72016173 ... -0.21519455 -1.49521575
#    0.4456064 ]]

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score
y_pred=svc.predict(x_test_std)
#print(b.append(accuracy_score(y_pred,y_test)))
#del b[-1]
print(b)
# Out:
# [0.8771929824561403]

# %%
from sklearn.metrics import confusion_matrix
z=confusion_matrix(y_pred,y_test)
sns.heatmap(z,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            B       1.00      0.63      0.77       171
#            M       0.00      0.00      0.00         0
#
#     accuracy                           0.63       171
#    macro avg       0.50      0.32      0.39       171
# weighted avg       1.00      0.63      0.77       171
# E:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
from sklearn.metrics import accuracy_score
print(b.append(accuracy_score(y_test,y_pred)))
print(b)
# Out:
# None
# [0.8771929824561403, 0.9298245614035088, 0.9239766081871345]

# %%
fe=rf.feature_importances_
print(fe)
# Out:
# [0.12226184 0.05541515 0.16717856 0.0890057  0.03200013 0.06019139
#  0.14328431 0.29251827 0.01999506 0.01814958]

# %%
import matplotlib.pyplot as plt
plt.bar(range(0,x.shape[1]),fe)
# Out:
# <BarContainer object of 10 artists>

# %%
print(x.shape)
# Out:
# (569, 29)

# %%
del b[-1]
print(b)
# Out:
# [0.8771929824561403, 0.9298245614035088]

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier().fit(x,y)
sm=SelectFromModel(model,prefit=True)
x_new=sm.transform(x)
print(x_new)
# Out:
# [[1.799e+01 1.228e+02 1.001e+03 3.001e-01 1.471e-01]
#  [2.057e+01 1.329e+02 1.326e+03 8.690e-02 7.017e-02]
#  [1.969e+01 1.300e+02 1.203e+03 1.974e-01 1.279e-01]
#  ...
#  [1.660e+01 1.083e+02 8.581e+02 9.251e-02 5.302e-02]
#  [2.060e+01 1.401e+02 1.265e+03 3.514e-01 1.520e-01]
#  [7.760e+00 4.792e+01 1.810e+02 0.000e+00 0.000e+00]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
rc=RandomForestClassifier()
rc.fit(x_train,y_train)
y_pred=rf.predict(x_test)
from sklearn.metrics import accuracy_score
print('Testing Acc=',accuracy_score(y_test,y_pred))
#getting 97 after doing standardization else getting 36%.
# Out:
# Testing Acc= 0.9239766081871345

# %%
#Feature extraction 
from sklearn.decomposition import PCA
pca=PCA(n_components=5)
pca.fit(x_train)
x_train_pca=pca.transform(x_train)
x_test_pca=pca.transform(x_test)
rf=RandomForestClassifier()
rf.fit(x_train_pca,y_train)
y_pred=rf.predict(x_test_pca)
from sklearn.metrics import accuracy_score
print('Testing Acc=',accuracy_score(y_test,y_pred))
# Out:
# Testing Acc= 0.9181286549707602

# %%
from sklearn.metrics import confusion_matrix
z=confusion_matrix(y_pred,y_test)
sns.heatmap(z,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      0.92      0.94       112
#            M       0.86      0.92      0.89        59
#
#     accuracy                           0.92       171
#    macro avg       0.91      0.92      0.91       171
# weighted avg       0.92      0.92      0.92       171

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier

# %%
from sklearn.naive_bayes import GaussianNB
cl=GaussianNB()
cl.fit(x_train,y_train)
y_pred=cl.predict(x_test)
from sklearn.metrics import accuracy_score
print(b.append(accuracy_score(y_test,y_pred)))
# Out:
# None

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.94      0.91      0.92       111
#            M       0.84      0.88      0.86        60
#
#     accuracy                           0.90       171
#    macro avg       0.89      0.90      0.89       171
# weighted avg       0.90      0.90      0.90       171

# %%
from sklearn.neighbors import KNeighborsClassifier
cl=KNeighborsClassifier()
cl.fit(x_train,y_train)
y_pred=cl.predict(x_test)
from sklearn.metrics import accuracy_score
print(b.append(accuracy_score(y_test,y_pred)))
# Out:
# None

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.91      0.88      0.89       112
#            M       0.78      0.83      0.80        59
#
#     accuracy                           0.86       171
#    macro avg       0.84      0.85      0.85       171
# weighted avg       0.86      0.86      0.86       171

# %%
from sklearn.tree import DecisionTreeClassifier
cl=DecisionTreeClassifier()
cl.fit(x_train,y_train)
y_pred=cl.predict(x_test)
from sklearn.metrics import accuracy_score
print(b.append(accuracy_score(y_test,y_pred)))
# Out:
# None

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.94      0.91      0.93       112
#            M       0.84      0.90      0.87        59
#
#     accuracy                           0.91       171
#    macro avg       0.89      0.90      0.90       171
# weighted avg       0.91      0.91      0.91       171

# %%
from sklearn.ensemble import AdaBoostClassifier
cl=AdaBoostClassifier()
cl.fit(x_train,y_train)
y_pred=cl.predict(x_test)
from sklearn.metrics import accuracy_score
print(b.append(accuracy_score(y_test,y_pred)))
# Out:
# None

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.96      0.95      0.95       110
#            M       0.90      0.93      0.92        61
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.94      0.94       171
# weighted avg       0.94      0.94      0.94       171

# %%
from sklearn.ensemble import ExtraTreesClassifier
cl=ExtraTreesClassifier()
cl.fit(x_train,y_train)
y_pred=cl.predict(x_test)
from sklearn.metrics import accuracy_score
print((accuracy_score(y_test,y_pred)))
# Out:
# 0.9181286549707602

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.96      0.94      0.95       111
#            M       0.89      0.93      0.91        60
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.94      0.93       171
# weighted avg       0.94      0.94      0.94       171

# %%
print(b)
a={"SVM":1,"Random Forest":2,"Naive Bayes":3,"KNN":4,"Random Forest":5,"Ada Boost":6,"Extra Tree":7}
#sns.barplot(data=a.values())
# Out:
# [0.8771929824561403, 0.9298245614035088, 0.9005847953216374, 0.8596491228070176, 0.8947368421052632, 0.935672514619883, 0.9122807017543859]
